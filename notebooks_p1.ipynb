# %%
#PRACHI PILLAY AIDS A 14
present= int(input("human present(1/0):"))
outside= int(input("outside light available(1/0): "))
if present==1 and outside ==0:
    print("LIGHT ON")
else:
    print("LIGHT OFF")
# Out:
# human present(1/0): 0
# outside light available(1/0):  1
# LIGHT OFF
