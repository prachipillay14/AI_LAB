# %%
#PRACHI PILLAY AIDS A 14
model = {
    "A": "normal", "B": "normal", "C": "normal"
}
for p in model.keys():
    print(f"\nPatient {p}")
    present = input("Patient is (critical/normal): ")
    model[p] = present
    if model[p] == "critical":
        print("ALERT")
    else:
        print("Continue monitoring")
print("\nFinal Model State:", model)
